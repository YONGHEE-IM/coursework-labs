# %% [markdown]
# # 우주선 게임
#
# 게임에서 플레이어가 화면 아래쪽 중앙에 나타나는 우주선을 조정합니다. 화살표를 사용하여 좌우로 움직이고, 스페이스 키를 눌러 탄환을 발사합니다. 게임이 시작되면 적 함대가 좌우로 움직이며 점점 내려옵니다. 적 함대를 모두 물리치면 이전 함대보다 더 빨리 움직이는 세 함대가 나타납니다. 적과 부딪히거나 화면 아래쪽에 적 우주선이 닿으면 플레이어 우주선이 폭발합니다.

# %% [markdown]
# ## 창 만들고 사용자 입력 처리

# %%
 # universe_war.py

import sys
import pygame
# 세팅 모듈 임포트
from settings import Settings

# 게임의 메인 처리부를 담당하는 클래스

class universeWar:
    """게임의 전체의 자원과 공작을 관리하는 클래스"""

    def __init__(self):
        pygame.init()    # 파이게임 초기화

        # Settings 인스턴스 생성
        self.settings = Settings()   # Settings 타입의 객체를 생성해서 멤버 변수에 연결

        self.screen = pygame.display.set_mode((self.settings.screen_width,
                                               self.settings.screen_height))   #해상도
        pygame.display.set_caption("Universe War")   # 제목 표시줄 설정

        # se;f.bg_color = (230, 230, 230)   # 배경색 지정

    def run_game(self):
        while True:
            # 키보드와 마우스 이벤트를 주시합니다.
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    pygame.quit()
                    sys.exit()

            # 가장 최근에 그려진 화면을 표시합니다.
            self.screen.fill(self.settings.bg_color)

            # 우주선을 그립니다.
            self.ship.blitme()

            pygame.display.flip()

# 게임 객체를 생성합니다.
game = UniverseWar()
game.run_game

# %% [markdown]
# ### 배경색 지정
# 배경색을 바꿔봅니다.

# %% [markdown]
# ### Setting 클래스
#
# 게임에 새 기능을 추가할 떄는 일반적으로 그에 필요한 세팅을 추가합니다. 메인 코드에 세팅을 추가하기 보다 Settings 모듈을 만들고 이 모듈에서 게임 세팅을 처리하는 것이 효율적입니다.
#
# 게임 제작 폴더에 setting.py를 생성하고 다음과 같이 Settings 클래스를 정의합니다.

# %%
class settings:
    """게임의 세팅을 저장하는 클래스"""

    def __init__(self):
        # 화면 세팅
        self.screen_width = 1200
        self.screen_height = 800
        self.bg_color = (230, 230, 230)

# %% [markdown]
# ## 우주선 이미지 출력
#
# 우주선을 추가해 보겠습니다. 이미지를 불러온 다음 파이게임의 blit() 메서드를 써서 화면에 그립니다. 이미지는 가능하면 배경색이 투명하거나 화면의 배경색과 같은 배경색을 같는 그림이 좋겠습니다. 현재 프로젝트 폴더에 images 폴더를 생성하고 게임에 사용할 이미지를 저장하겠습니다.

# %% [markdown]
# ### Ship 클래스
#
# 우주선을 만들기 위해 ship 클래스를 정의할 ship.py 모듈을 생성합니다. 이 클래스에서 플레이어의 우주선 동작을 담당합니다.

# %%
import pygame

class ship:
    """우주선을 관리하는 클래스"""
    def __init__(self, uw_game):  # 메인모듈의 UniverseWar 클래스 타입 객체를 두번째 
                                  # 매개 변수로 받아 ship 클래스에서 사용합니다. 
        self.screen = uw_game.screen    # 게임 화면에 접근하기 위해 매개변수에 연결된 게임 객체의 screen 멤버에 접근

        self.screen_rect = uw_game.screen_get_rect()
        # 우주선 이미지를 가져와서 저장합니다. 
        self.image = pygame.image.load('images/ship.png')
        self.rect = self.image.get_rect()    # 우주선 그림의 직사각형 영역 정보를 가져옵니다. 

        self.rect.midbottom = self.screen_rect.midbottom   # 우주선 그림을 화면 중앙 아랫쪽에 배치합니다. 

    def blitme(self):    # 우주선 그림을 해당 영역에 그립니다. 
        self.screen.blit(self.image, self.rect)

# %% [markdown]
# rect 객체에서 사각형의 네 방향 가장자리와 중심의 x, y 좌표를 사용해 객체의 위치를 정할 수 있습니다. 게임 요소의 중심을 기준으로 움직일때 center, centerx, centery 속성을 사용합니다. 화면 경계를 움직일 때는 top, bottom, left, right 속성을 사용합니다. 이들을 조합한 midbottom, midtop, midleft, midright 속성도 있습니다. 사각형의 위치를 정할 때는 왼쪽 상단 모서리의 x, y 좌표인 x y 속성을 사용합니다.
#
# 파이게임에서 원점(0, 0)은 화면의 왼쪽 상단 모서리입니다. x값은 오른쪽으로 갈수록 증가하고 y값은 아래로 갈수록 증가합니다.

# %% [markdown]
# ### 화면에 우주선 출력

# %%
 # universe_war.py

import sys
import pygame
# 세팅 모듈 임포트
from settings import Settings
from ship import Ship

# 게임의 메인 처리부를 담당하는 클래스

class universeWar:
    """게임의 전체의 자원과 공작을 관리하는 클래스"""

    def __init__(self):
        pygame.init()    # 파이게임 초기화

        # Settings 인스턴스 생성
        self.settings = Settings()   # Settings 타입의 객체를 생성해서 멤버 변수에 연결

        self.screen = pygame.display.set_mode((self.settings.screen_width,
                                               self.settings.screen_height))   #해상도
        pygame.display.set_caption("Universe War")   # 제목 표시줄 설정

        self.ship = Ship(self)     # 우주선 객체 생성후 변수에 연결

        # se;f.bg_color = (230, 230, 230)   # 배경색 지정

    def run_game(self):
        while True:
            self._check_events()
       
            # 가장 최근에 그려진 화면을 표시합니다.
            self.screen.fill(self.settings.bg_color)

            # 우주선을 그립니다.
            self.ship.blitme()

            pygame.display.flip()

    def _check_events(self):
         # 키보드와 마우스 이벤트를 주시합니다.
         for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == pygame.KEYDOWN:   # 키가 눌렸고
                if event.key == pygame.K_RIGHT:  # 눌린 키가 오른쪽 방향키라면
                    self.ship.rect.x += 1

    def _update_screen(self):
        self.screen.fill(self.setting.bg_color)

        # 우주선을 그립니다.
        self.ship.blitme()

        pygame.display.flip()
        

# 게임 객체를 생성합니다.
game = UniverseWar()
game.run_game
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 6
#       4 import pygame
#       5 # 세팅 모듈 임포트
# ----> 6 from settings import Settings
#       7 from ship import Ship
#       9 # 게임의 메인 처리부를 담당하는 클래스
#
# ModuleNotFoundError: No module named 'settings'

# %% [markdown]
# ### 리팩터링
#
# run_game() 메서드를 보조 메서드 두개로 나누어 보겠습니다. 보조 메서드는 클래스 안에서 동작하지만 인스턴스 외부에서 호출하지 않는 메서드 입니다. 파이썬에서는 메서드 이름 앞에 밑줄을 한개 써서 보조 메서드를 표시합니다.
#
# 게임안에서 발생하는 이벤트를 처리하는 코드를 _check_events() 메서드로 옮깁니다.

# %% [markdown]
# ### 우주선 조종하기
#
# 플레이어가 오른쪽이나 왼쪽 방향키를 눌렀을 때 우주선을 움직이는 코드를 작성합니다. 먼저 오른쪽으로 움직이는 코드를 작성하고 같은 방법으로 왼쪽으로 움직이는 코드도 만들겠습니다.

# %% [markdown]
# ### 키 입력 처리
#
# 사용자가 키를 누르면 KEYDOWN 이벤트가 발생합니다. 이베느가 감지되면 그 키가 특정 동작을 일으키는 키인지 체크해야 합니다. 예를 들어 오른쪽 화살표 키를 누르면 우주선의 rect.x 값을 증가시켜 우주선을 오른쪽으로 이동시킵니다.

# %% [markdown]
# ### 키보드를 누르고 있는 동안 이동 지속하기
#
# 파이게임에서는 pygame.KEYUP 이벤트를 감지하여 사용자가 누르던 키에서 손을 뗀 것을 감지합니다. KEYDOWN과 KEYUP 이벤트를 조합하여 moving_right 플래그를 만들면 연속적인 이동을 구현할 수 있습니다.
#
# moving_right 플래그가 False 이면 우주선은 정지상태이고 플레이어가 오른쪽 화살표를 누르면 해당 플래그를 True로 바꾸고 손을 떼면 False로 바꿉니다.
#
# 우주선에 대한 코드는 ship 모듈에 있으므로 모듈의 클래스에 moving_right 속성과 플레그를 체크하는 update() 메서드를 추가합니다.

# %%
 # universe_war.py

import sys
import pygame
# 세팅 모듈 임포트
from settings import Settings
from ship import Ship

# 게임의 메인 처리부를 담당하는 클래스

class universeWar:
    """게임의 전체의 자원과 공작을 관리하는 클래스"""

    def __init__(self):
        pygame.init()    # 파이게임 초기화

        # Settings 인스턴스 생성
        self.settings = Settings()   # Settings 타입의 객체를 생성해서 멤버 변수에 연결

        self.screen = pygame.display.set_mode((self.settings.screen_width,
                                               self.settings.screen_height))   #해상도
        pygame.display.set_caption("Universe War")   # 제목 표시줄 설정

        self.ship = Ship(self)     # 우주선 객체 생성후 변수에 연결

        # se;f.bg_color = (230, 230, 230)   # 배경색 지정

    def run_game(self):
        while True:
            self._check_events()
       
            # 가장 최근에 그려진 화면을 표시합니다.
            self.screen.fill(self.settings.bg_color)

            # 우주선을 그립니다.
            self.ship.blitme()

            pygame.display.flip()

    def _check_events(self):
         # 키보드와 마우스 이벤트를 주시합니다.
         for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == pygame.KEYDOWN:   # 키가 눌렸고
                if event.key == pygame.K_RIGHT:  # 눌린 키가 오른쪽 방향키라면
                    self.ship.moving_right = True

            elif event.type == pygame.KEYUP:  # 키를 눌렀다가 띄었고 
                if event.key == pygame.K_RIGHT:
                    self.ship.moving_right = False

    def _update_screen(self):
        self.screen.fill(self.setting.bg_color)

        # 우주선을 그립니다.
        self.ship.blitme()

        pygame.display.flip()
        

# 게임 객체를 생성합니다.
game = UniverseWar()
game.run_game

# %% [markdown]
# ### 좌우로 움직이기
#
# 우주선을 왼쪽으로 움직이도록 코드를 추가하겠습니다. ship 클래스와 _check_event() 메서드를 수정합니다. ship 클래스의 __init__()과 update()를 수정합니다.

# %%
 # universe_war.py

import sys
import pygame
# 세팅 모듈 임포트
from settings import Settings
from ship import Ship

# 게임의 메인 처리부를 담당하는 클래스

class universeWar:
    """게임의 전체의 자원과 공작을 관리하는 클래스"""

    def __init__(self):
        pygame.init()    # 파이게임 초기화

        # Settings 인스턴스 생성
        self.settings = Settings()   # Settings 타입의 객체를 생성해서 멤버 변수에 연결

        self.screen = pygame.display.set_mode((self.settings.screen_width,
                                               self.settings.screen_height))   #해상도
        pygame.display.set_caption("Universe War")   # 제목 표시줄 설정

        self.ship = Ship(self)     # 우주선 객체 생성후 변수에 연결

        # se;f.bg_color = (230, 230, 230)   # 배경색 지정

    def run_game(self):
        while True:
            self._check_events()
       
            # 가장 최근에 그려진 화면을 표시합니다.
            self.screen.fill(self.settings.bg_color)

            # 우주선을 그립니다.
            self.ship.blitme()

            pygame.display.flip()

    def _check_events(self):
         # 키보드와 마우스 이벤트를 주시합니다.
         for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == pygame.KEYDOWN:   # 키가 눌렸고
                if event.key == pygame.K_RIGHT:  # 눌린 키가 오른쪽 방향키라면
                    self.ship.moving_right = True
                elif event.key == pygame.K_LEFT:   # 눌린 키가 왼쪽 방향키라면
                    self.ship.moving_left = True

            elif event.type == pygame.KEYUP:  # 키를 눌렀다가 띄었고 
                if event.key == pygame.K_RIGHT:
                    self.ship.moving_right = False
                elif event.key == pygame.K_LEFT:
                    self.ship.moving_left = False

    def _update_screen(self):
        self.screen.fill(self.setting.bg_color)

        # 우주선을 그립니다.
        self.ship.blitme()

        pygame.display.flip()
        

# 게임 객체를 생성합니다.
game = UniverseWar()
game.run_game
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 6
#       4 import pygame
#       5 # 세팅 모듈 임포트
# ----> 6 from settings import Settings
#       7 from ship import Ship
#       9 # 게임의 메인 처리부를 담당하는 클래스
#
# ModuleNotFoundError: No module named 'settings'

# %% [markdown]
# ### 우주선 속도 조정
#
# Settings 클래스에 ship_speed 속성을 추가하여 우주선 속도를 조절해보겠습니다.

# %%
class settings:
    """게임의 세팅을 저장하는 클래스"""

    def __init__(self):
        # 화면 세팅
        self.screen_width = 1200
        self.screen_height = 800
        self.bg_color = (230, 230, 230)

        # 우주선 세팅
        self.ship_speed = 1.5

# %% [markdown]
# 속도 세팅에 소수점이 있는 값을 사용했으므로 게임의 전체적인 속도를 올릴 때 더 세밀하게 조정가능합니다.
# 하지만 x와 같은 rect의 속성은 오직 정수 값만 사용하므로 Ship 클래스도 수정해야 합니다.

# %%
import pygame

class Ship:
    """우주선을 관리하는 클래스"""
    def __init__(self, uw_game):  # 메인모듈의 UniverseWar 클래스 타입 객체를 두번째 
                                  # 매개 변수로 받아 ship 클래스에서 사용합니다. 
        self.screen = uw_game.screen    # 게임 화면에 접근하기 위해 매개변수에 연결된 게임 객체의 screen 멤버에 접근

        self.settings = uw_game.settings     # ship_speed 속성은 UniverseWar 타입 객체가 가지고 있으므로 멤버 변수에 일어와서 저장합니다. 
        self.screen_rect = uw_game.screen_get_rect()
        # 우주선 이미지를 가져와서 저장합니다. 
        self.image = pygame.image.load('images/ship.png')
        self.rect = self.image.get_rect()    # 우주선 그림의 직사각형 영역 정보를 가져옵니다. 

        self.rect.midbottom = self.screen_rect.midbottom   # 우주선 그림을 화면 중앙 아랫쪽에 배치합니다. 
        
        # 우주선의 가로 위치를 나타내는 소수점이 있는 값을 저장합니다.
        self.x = float(self.rect.x)
        
        self.moving_right = False
        self.moving_left = False

    def update(self):
        """움직임 플래그에 따라 우주선 위치를 갱신합니다."""
        if self.moving_right:
            self.x += self.settings.ship_speed

        if self.moving_left:
            self.x -= self.settings.ship_speed

        self.rect.x = self.x

    def blitme(self):    # 우주선 그림을 해당 영역에 그립니다. 
        self.screen.blit(self.image, self.rect)
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# universe_war.py

import sys
import pygame
# 세팅 모듈 임포트
from settings import Settings
from ship import Ship

# 게임의 메인 처리부를 담당하는 클래스

class universeWar:
    """게임의 전체의 자원과 공작을 관리하는 클래스"""

    def __init__(self):
        pygame.init()    # 파이게임 초기화

        # Settings 인스턴스 생성
        self.settings = Settings()   # Settings 타입의 객체를 생성해서 멤버 변수에 연결

        self.screen = pygame.display.set_mode((self.settings.screen_width,
                                               self.settings.screen_height))   #해상도
        pygame.display.set_caption("Universe War")   # 제목 표시줄 설정

        self.ship = Ship(self)     # 우주선 객체 생성후 변수에 연결

        # se;f.bg_color = (230, 230, 230)   # 배경색 지정

    def run_game(self):
        while True:
            self._check_events()
       
            # 가장 최근에 그려진 화면을 표시합니다.
            self.screen.fill(self.settings.bg_color)

            # 우주선을 그립니다.
            self.ship.blitme()

            pygame.display.flip()

    def _check_events(self):
         # 키보드와 마우스 이벤트를 주시합니다.
         for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == pygame.KEYDOWN:   # 키가 눌렸고
                if event.key == pygame.K_RIGHT:  # 눌린 키가 오른쪽 방향키라면
                    self.ship.moving_right = True
                elif event.key == pygame.K_LEFT:   # 눌린 키가 왼쪽 방향키라면
                    self.ship.moving_left = True

            elif event.type == pygame.KEYUP:  # 키를 눌렀다가 띄었고 
                if event.key == pygame.K_RIGHT:
                    self.ship.moving_right = False
                elif event.key == pygame.K_LEFT:
                    self.ship.moving_left = False

    def _update_screen(self):
        self.screen.fill(self.setting.bg_color)

        # 우주선을 그립니다.
        self.ship.blitme()

        pygame.display.flip()
        

# 게임 객체를 생성합니다.
game = UniverseWar()
game.run_game
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 import pygame
#       5 # 세팅 모듈 임포트
# ----> 6 from settings import Settings
#       7 from ship import Ship
#       9 # 게임의 메인 처리부를 담당하는 클래스
#
# ModuleNotFoundError: No module named 'settings'

# %% [markdown]
# ### 우주선 이동 범위 제한하기
#
# 우주선이 화면 경계 밖으로 사라지지 않도록 클리핑 처리를 해줍니다. 다음과 같이 ship의 update() 메서드를 수정합니다.

# %%
import pygame

class ship:
    """우주선을 관리하는 클래스"""
    def __init__(self, uw_game):  # 메인모듈의 UniverseWar 클래스 타입 객체를 두번째 
                                  # 매개 변수로 받아 ship 클래스에서 사용합니다. 
        self.screen = uw_game.screen    # 게임 화면에 접근하기 위해 매개변수에 연결된 게임 객체의 screen 멤버에 접근

        self.settings = uw_game.settings     # ship_speed 속성은 UniverseWar 타입 객체가 가지고 있으므로 멤버 변수에 일어와서 저장합니다. 
        self.screen_rect = uw_game.screen_get_rect()
        # 우주선 이미지를 가져와서 저장합니다. 
        self.image = pygame.image.load('images/ship.png')
        self.rect = self.image.get_rect()    # 우주선 그림의 직사각형 영역 정보를 가져옵니다. 

        self.rect.midbottom = self.screen_rect.midbottom   # 우주선 그림을 화면 중앙 아랫쪽에 배치합니다. 
        
        # 우주선의 가로 위치를 나타내는 소수점이 있는 값을 저장합니다.
        self.x = float(self.rect.x)
        
        self.moving_right = False
        self.moving_left = False

    def update(self):
        """움직임 플래그에 따라 우주선 위치를 갱신합니다."""
        if self.moving_right and self.rect.right < self.screen_rect.right:
            self.x += self.settings.ship_speed

        if self.moving_left and self.rect.left > 0:
            self.x -= self.settings.ship_speed

        self.rect.x = self.x

    def blitme(self):    # 우주선 그림을 해당 영역에 그립니다. 
        self.screen.blit(self.image, self.rect)

# %% [markdown]
# _check_events() 메서드 리팩터링
#
# _check_events() 메서드를 두 개로 나눕니다. 하나는 KEYDOWN 이벤트만 담당하고, 다른 하나는 KEYUP 이벤트만 담당합니다.

# %%
# universe_war.py

import sys
import pygame
# 세팅 모듈 임포트
from settings import Settings
from ship import Ship

# 게임의 메인 처리부를 담당하는 클래스

class universeWar:
    """게임의 전체의 자원과 공작을 관리하는 클래스"""

    def __init__(self):
        pygame.init()    # 파이게임 초기화

        # Settings 인스턴스 생성
        self.settings = Settings()   # Settings 타입의 객체를 생성해서 멤버 변수에 연결

        self.screen = pygame.display.set_mode((self.settings.screen_width,
                                               self.settings.screen_height))   #해상도
        pygame.display.set_caption("Universe War")   # 제목 표시줄 설정

        self.ship = Ship(self)     # 우주선 객체 생성후 변수에 연결

        # se;f.bg_color = (230, 230, 230)   # 배경색 지정

    def run_game(self):
        while True:
            self._check_events()
       
            # 가장 최근에 그려진 화면을 표시합니다.
            self.screen.fill(self.settings.bg_color)

            # 우주선을 그립니다.
            self.ship.blitme()

            pygame.display.flip()

    def _check_events(self):
         # 키보드와 마우스 이벤트를 주시합니다.
         for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == pygame.KEYDOWN:   # 키가 눌렸고
                self._check_keydown_events(event)
                
            elif event.type == pygame.KEYUP:  # 키를 눌렀다가 띄었고 
               self._check_keyup_events(event)

    def _check_keydown_events(self, event):
        if event.key == pygame.K_RIGHT:  # 눌린 키가 오른쪽 방향키라면
            self.ship.moving_right = True
        elif event.key == pygame.K_LEFT:   # 눌린 키가 왼쪽 방향키라면
            elf.ship.moving_left = True

    def _check_keyup_events(self, event):
        if event.key == pygame.K_RIGHT:
            self.ship.moving_right = False
        elif event.key == pygame.K_LEFT:
            self.ship.moving_left = False

        

    def _update_screen(self):
        self.screen.fill(self.setting.bg_color)

        # 우주선을 그립니다.
        self.ship.blitme()

        pygame.display.flip()
        

# 게임 객체를 생성합니다.
game = UniverseWar()
game.run_game
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 6
#       4 import pygame
#       5 # 세팅 모듈 임포트
# ----> 6 from settings import Settings
#       7 from ship import Ship
#       9 # 게임의 메인 처리부를 담당하는 클래스
#
# ModuleNotFoundError: No module named 'settings'

# %% [markdown]
# ### Q 키를 눌러 종료하기

# %%
# universe_war.py

import sys
import pygame
# 세팅 모듈 임포트
from settings import Settings
from ship import Ship

# 게임의 메인 처리부를 담당하는 클래스

class universeWar:
    """게임의 전체의 자원과 공작을 관리하는 클래스"""

    def __init__(self):
        pygame.init()    # 파이게임 초기화

        # Settings 인스턴스 생성
        self.settings = Settings()   # Settings 타입의 객체를 생성해서 멤버 변수에 연결

        self.screen = pygame.display.set_mode((self.settings.screen_width,
                                               self.settings.screen_height))   #해상도
        pygame.display.set_caption("Universe War")   # 제목 표시줄 설정

        self.ship = Ship(self)     # 우주선 객체 생성후 변수에 연결

        # se;f.bg_color = (230, 230, 230)   # 배경색 지정

    def run_game(self):
        while True:
            self._check_events()
       
            # 가장 최근에 그려진 화면을 표시합니다.
            self.screen.fill(self.settings.bg_color)

            # 우주선을 그립니다.
            self.ship.blitme()

            pygame.display.flip()

    def _check_events(self):
         # 키보드와 마우스 이벤트를 주시합니다.
         for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == pygame.KEYDOWN:   # 키가 눌렸고
                self._check_keydown_events(event)
                
            elif event.type == pygame.KEYUP:  # 키를 눌렀다가 띄었고 
               self._check_keyup_events(event)

    def _check_keydown_events(self, event):
        if event.key == pygame.K_RIGHT:  # 눌린 키가 오른쪽 방향키라면
            self.ship.moving_right = True
        elif event.key == pygame.K_LEFT:   # 눌린 키가 왼쪽 방향키라면
            elf.ship.moving_left = True
        elif event.key == pygame.k_q:     # 프로그램 실행중 q 키가 입력으로 들어오면 종료
            pygame.quit()
            sys.exit()

    def _check_keyup_events(self, event):
        if event.key == pygame.K_RIGHT:
            self.ship.moving_right = False
        elif event.key == pygame.K_LEFT:
            self.ship.moving_left = False

        

    def _update_screen(self):
        self.screen.fill(self.setting.bg_color)

        # 우주선을 그립니다.
        self.ship.blitme()

        pygame.display.flip()
        

# 게임 객체를 생성합니다.
game = UniverseWar()
game.run_game

# %% [markdown]
# ### 전체화면 모드에서 게임실행
# 다음과 같이 __init__() 함수를 수정합니다.

# %%
# universe_war.py

import sys
import pygame
# 세팅 모듈 임포트
from settings import Settings
from ship import Ship

# 게임의 메인 처리부를 담당하는 클래스

class universeWar:
    """게임의 전체의 자원과 공작을 관리하는 클래스"""

    def __init__(self):
        pygame.init()    # 파이게임 초기화

        # Settings 인스턴스 생성
        self.settings = Settings()   # Settings 타입의 객체를 생성해서 멤버 변수에 연결

        self.screen = pygame.display.set_mode((0, 0), pygame.FULLSCREEN)  #해상도
        self.settings.screen_width = self.screen.get_rect().width
        self.settings.screen_height = self.screen.get_rect().height

        
        pygame.display.set_caption("Universe War")   # 제목 표시줄 설정

        self.ship = Ship(self)     # 우주선 객체 생성후 변수에 연결

        # se;f.bg_color = (230, 230, 230)   # 배경색 지정

    def run_game(self):
        while True:
            self._check_events()
       
            # 가장 최근에 그려진 화면을 표시합니다.
            self.screen.fill(self.settings.bg_color)

            # 우주선을 그립니다.
            self.ship.blitme()

            pygame.display.flip()

    def _check_events(self):
         # 키보드와 마우스 이벤트를 주시합니다.
         for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == pygame.KEYDOWN:   # 키가 눌렸고
                self._check_keydown_events(event)
                
            elif event.type == pygame.KEYUP:  # 키를 눌렀다가 띄었고 
               self._check_keyup_events(event)

    def _check_keydown_events(self, event):
        if event.key == pygame.K_RIGHT:  # 눌린 키가 오른쪽 방향키라면
            self.ship.moving_right = True
        elif event.key == pygame.K_LEFT:   # 눌린 키가 왼쪽 방향키라면
            elf.ship.moving_left = True
        elif event.key == pygame.k_q:     # 프로그램 실행중 q 키가 입력으로 들어오면 종료
            pygame.quit()
            sys.exit()

    def _check_keyup_events(self, event):
        if event.key == pygame.K_RIGHT:
            self.ship.moving_right = False
        elif event.key == pygame.K_LEFT:
            self.ship.moving_left = False

        

    def _update_screen(self):
        self.screen.fill(self.setting.bg_color)

        # 우주선을 그립니다.
        self.ship.blitme()

        pygame.display.flip()
        

# 게임 객체를 생성합니다.
game = UniverseWar()
game.run_game
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 6
#       4 import pygame
#       5 # 세팅 모듈 임포트
# ----> 6 from settings import Settings
#       7 from ship import Ship
#       9 # 게임의 메인 처리부를 담당하는 클래스
#
# ModuleNotFoundError: No module named 'settings'

# %% [markdown]
# ### 탄환 발사
#
# 스페이스 키를 누르면 탄환이 발사되며 탄환은 작은 직사각형으로 표시하겠습니다. 탄환은 화면 상단을 향해 직선으로 날아가고, 화면 상단에 도착하면 사라집니다.
#
# 다음과 같이 settings.py 모듈을 수정하여 Bullet 속성을 추가합니다.

# %%
class Settings:
    """게임의 세팅을 저장하는 클래스"""

    def __init__(self):
        # 화면 세팅
        self.screen_width = 1200
        self.screen_height = 800
        self.bg_color = (230, 230, 230)

        # 우주선 세팅
        self.ship_speed = 1.5

        # 탄환 세팅
        self.bullet_speed = 1.0
        self.bullet_width = 3
        self.bullet_height = 15
        self.bullet_color = (60, 60, 60)

# %% [markdown]
# ### Bullet 클래스
#
# bullet.py 파일을 생성하고 다음과 같이 클래스를 작성합니다.

# %%
# bullet.py

import pygame
from pygame.sprite import Sprite

class bullet(Sprite):
    """우주선에서 발사하는 탄환을 관리하는 클래스"""
    def __init__(self, uw_game):
        super().__init__()
        self.screen = uw_game.screen
        self.settings = uw_game.settings
        self.color = self.settings.bullet_color 

        # (0, 0)에 탄환 사각형을 만들고 정확한 위치를 지정합니다. 
        self.rect = pygame.Rect(0, 0, self.settings.bullet_width,
                                self.settings.bullet_height)
        self.rect.midtop = uw_game.ship.rect.midtop  # 총알은 우주선의 꼭대기에서 발사되므로 위치 지정 
        self.y = float(self.rect.y) 

    # 탄환의 위치를 갱신합니다.

    def update(self):
        self.y -= self.settings.bullet_speed
        self.rect.y = self.y

    def draw_bullet(self):
        # 탄환을 화면에 그립니다.
        pygame.draw.rect(self.screen, self.color, self.rect)

# %% [markdown]
# ### 탄환을 그룹으로 저장
#
# 게임에서는 그룹을 만들어 발사된 탄환을 모두 저장합니다. 그룹은 pygame.sprite.Group 클래스의 인스턴스입니다. 이 클래스는 리스트와 마찬가지로 동작하며 게임을 만드는데 도움이 되는 기능도 가지고 있습니다.

# %%
# universe_war.py

import sys
import pygame
# 세팅 모듈 임포트
from settings import Settings
from ship import Ship

# 게임의 메인 처리부를 담당하는 클래스

class universeWar:
    """게임의 전체의 자원과 공작을 관리하는 클래스"""

    def __init__(self):
        pygame.init()    # 파이게임 초기화

        # Settings 인스턴스 생성
        self.settings = Settings()   # Settings 타입의 객체를 생성해서 멤버 변수에 연결

        self.screen = pygame.display.set_mode((0, 0), pygame.FULLSCREEN)  #해상도
        self.settings.screen_width = self.screen.get_rect().width
        self.settings.screen_height = self.screen.get_rect().height

        
        pygame.display.set_caption("Universe War")   # 제목 표시줄 설정

        self.ship = Ship(self)     # 우주선 객체 생성후 변수에 연결

        # se;f.bg_color = (230, 230, 230)   # 배경색 지정

        self.bullets = pygame.sprite_Group()

    def run_game(self):
        while True:
            self._check_events()
       
            # 가장 최근에 그려진 화면을 표시합니다.
            self.screen.fill(self.settings.bg_color)

            # 우주선을 그립니다.
            self.ship.blitme()

            pygame.display.flip()

    def _check_events(self):
         # 키보드와 마우스 이벤트를 주시합니다.
         for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == pygame.KEYDOWN:   # 키가 눌렸고
                self._check_keydown_events(event)
                
            elif event.type == pygame.KEYUP:  # 키를 눌렀다가 띄었고 
               self._check_keyup_events(event)

    def _check_keydown_events(self, event):
        if event.key == pygame.K_RIGHT:  # 눌린 키가 오른쪽 방향키라면
            self.ship.moving_right = True
        elif event.key == pygame.K_LEFT:   # 눌린 키가 왼쪽 방향키라면
            elf.ship.moving_left = True
        elif event.key == pygame.k_q:     # 프로그램 실행중 q 키가 입력으로 들어오면 종료
            pygame.quit()
            sys.exit()

    def _check_keyup_events(self, event):
        if event.key == pygame.K_RIGHT:
            self.ship.moving_right = False
        elif event.key == pygame.K_LEFT:
            self.ship.moving_left = False

        

    def _update_screen(self):
        self.screen.fill(self.setting.bg_color)

        # 우주선을 그립니다.
        self.ship.blitme()

        pygame.display.flip()
        

# 게임 객체를 생성합니다.
game = UniverseWar()
game.run_game

# %% [markdown]
# while 루프를 반복할 때마다 탄환 위치를 갱신합니다.

# %%
# universe_war.py

import sys
import pygame
# 세팅 모듈 임포트
from settings import Settings
from ship import Ship

# 게임의 메인 처리부를 담당하는 클래스

class universeWar:
    """게임의 전체의 자원과 공작을 관리하는 클래스"""

    def __init__(self):
        pygame.init()    # 파이게임 초기화

        # Settings 인스턴스 생성
        self.settings = Settings()   # Settings 타입의 객체를 생성해서 멤버 변수에 연결

        self.screen = pygame.display.set_mode((0, 0), pygame.FULLSCREEN)  #해상도
        self.settings.screen_width = self.screen.get_rect().width
        self.settings.screen_height = self.screen.get_rect().height

        
        pygame.display.set_caption("Universe War")   # 제목 표시줄 설정

        self.ship = Ship(self)     # 우주선 객체 생성후 변수에 연결

        # se;f.bg_color = (230, 230, 230)   # 배경색 지정

    def run_game(self):
        while True:
            self._check_events()
       
            # 가장 최근에 그려진 화면을 표시합니다.
            self.ship.update()
            self.bullets.update()
            self._update_
    def _check_events(self):
         # 키보드와 마우스 이벤트를 주시합니다.
         for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == pygame.KEYDOWN:   # 키가 눌렸고
                self._check_keydown_events(event)
                
            elif event.type == pygame.KEYUP:  # 키를 눌렀다가 띄었고 
               self._check_keyup_events(event)

    def _check_keydown_events(self, event):
        if event.key == pygame.K_RIGHT:  # 눌린 키가 오른쪽 방향키라면
            self.ship.moving_right = True
        elif event.key == pygame.K_LEFT:   # 눌린 키가 왼쪽 방향키라면
            elf.ship.moving_left = True
        elif event.key == pygame.k_q:     # 프로그램 실행중 q 키가 입력으로 들어오면 종료
            pygame.quit()
            sys.exit()

    def _check_keyup_events(self, event):
        if event.key == pygame.K_RIGHT:
            self.ship.moving_right = False
        elif event.key == pygame.K_LEFT:
            self.ship.moving_left = False

        

    def _update_screen(self):
        self.screen.fill(self.setting.bg_color)

        # 우주선을 그립니다.
        self.ship.blitme()

        pygame.display.flip()
        

# 게임 객체를 생성합니다.
game = UniverseWar()
game.run_game

# %% [markdown]
# ### 탄환 발사
#
# 스페이스 키를 누를 때 탄환을 발사하려면 UniverseWar 클래스의 _check_keydown_events() 메서드를 수정하여 스페이스 키가 눌렀을 때 처리해줘야 합니다. 손을 뗄 때는 아무일도 하지 않으므로 keyup 이벤트는 수정하지 않습니다. _update_screen() 도 수정하여 flip()을 호출하기 전에 모든 탄환을 화면에 그립니다.
#
# 이 동작들을 처리할 _fire_bullet() 메서드를 작성합니다.

# %%
# universe_war.py

import sys
import pygame
# 세팅 모듈 임포트
from settings import Settings
from ship import Ship
from bullet import Bullet

# 게임의 메인 처리부를 담당하는 클래스

class universeWar:
    """게임의 전체의 자원과 공작을 관리하는 클래스"""

    def __init__(self):
        pygame.init()    # 파이게임 초기화

        # Settings 인스턴스 생성
        self.settings = Settings()   # Settings 타입의 객체를 생성해서 멤버 변수에 연결

        self.screen = pygame.display.set_mode((0, 0), pygame.FULLSCREEN)  #해상도
        self.settings.screen_width = self.screen.get_rect().width
        self.settings.screen_height = self.screen.get_rect().height

        
        pygame.display.set_caption("Universe War")   # 제목 표시줄 설정

        self.ship = Ship(self)     # 우주선 객체 생성후 변수에 연결

        # se;f.bg_color = (230, 230, 230)   # 배경색 지정

    def run_game(self):
        while True:
            self._check_events()
       
            # 가장 최근에 그려진 화면을 표시합니다.
            self.ship.update()
            self.bullets.update()
            self._update_
    def _check_events(self):
         # 키보드와 마우스 이벤트를 주시합니다.
         for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == pygame.KEYDOWN:   # 키가 눌렸고
                self._check_keydown_events(event)
                
            elif event.type == pygame.KEYUP:  # 키를 눌렀다가 띄었고 
               self._check_keyup_events(event)

    def _check_keydown_events(self, event):
        if event.key == pygame.K_RIGHT:  # 눌린 키가 오른쪽 방향키라면
            self.ship.moving_right = True
        elif event.key == pygame.K_LEFT:   # 눌린 키가 왼쪽 방향키라면
            elf.ship.moving_left = True
        elif event.key == pygame.k_q:     # 프로그램 실행중 q 키가 입력으로 들어오면 종료
            pygame.quit()
            sys.exit()
        elif event.key == pygame.K_SPACE:
            self._fire_bullet()
            

    def _check_keyup_events(self, event):
        if event.key == pygame.K_RIGHT:
            self.ship.moving_right = False
        elif event.key == pygame.K_LEFT:
            self.ship.moving_left = False

    def _fire_bullet(self):
        """새 탄환을 생성하고 bullets 그룹에 추가"""
        new_bullet = Bullet(self)
        self.bullets.add(new_bullet)

        

    def _update_screen(self):
        self.screen.fill(self.setting.bg_color)

        # 우주선을 그립니다.
        self.ship.blitme()

        for bullet in self.bullets.sprites():
            bullet.draw_bullet()

        pygame.display.flip()
        

# 게임 객체를 생성합니다.
game = UniverseWar()
game.run_game

# %% [markdown]
# ### 사라진 탄환 제거
#
# 화면에서 벗어난 탄환은 계속해서 메모리와 CPU 자원을 소모하기 때문에 문제가 발생 할수 있습니다. 화면을 벗어난 탄환을 제거하려면 탄환객체의 rect의 bottom 값이 0이 되는 순간(화면의 맨위에 도달한 순간)을 감지해야 합니다.

# %%
# universe_war.py

import sys
import pygame
# 세팅 모듈 임포트
from settings import Settings
from ship import Ship
from bullet import Bullet

# 게임의 메인 처리부를 담당하는 클래스

class universeWar:
    """게임의 전체의 자원과 공작을 관리하는 클래스"""

    def __init__(self):
        pygame.init()    # 파이게임 초기화

        # Settings 인스턴스 생성
        self.settings = Settings()   # Settings 타입의 객체를 생성해서 멤버 변수에 연결

        self.screen = pygame.display.set_mode((0, 0), pygame.FULLSCREEN)  #해상도
        self.settings.screen_width = self.screen.get_rect().width
        self.settings.screen_height = self.screen.get_rect().height

        
        pygame.display.set_caption("Universe War")   # 제목 표시줄 설정

        self.ship = Ship(self)     # 우주선 객체 생성후 변수에 연결

        # se;f.bg_color = (230, 230, 230)   # 배경색 지정

    def run_game(self):
        while True:
            self._check_events()
       
            # 가장 최근에 그려진 화면을 표시합니다.
            self.ship.update()
            self.bullets.update()
            

            # 사라진 탄환을 제거합니다.
            for bullet in self.bullets.copy():
                if bullet.rect.bottom <= 0:
                    self.bullets.remove(bullet)

            self._update_screen()
            
    def _check_events(self):
         # 키보드와 마우스 이벤트를 주시합니다.
         for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == pygame.KEYDOWN:   # 키가 눌렸고
                self._check_keydown_events(event)
                
            elif event.type == pygame.KEYUP:  # 키를 눌렀다가 띄었고 
               self._check_keyup_events(event)

    

    def _check_keydown_events(self, event):
        if event.key == pygame.K_RIGHT:  # 눌린 키가 오른쪽 방향키라면
            self.ship.moving_right = True
        elif event.key == pygame.K_LEFT:   # 눌린 키가 왼쪽 방향키라면
            elf.ship.moving_left = True
        elif event.key == pygame.k_q:     # 프로그램 실행중 q 키가 입력으로 들어오면 종료
            pygame.quit()
            sys.exit()
        elif event.key == pygame.K_SPACE:
            self._fire_bullet()
            

    def _check_keyup_events(self, event):
        if event.key == pygame.K_RIGHT:
            self.ship.moving_right = False
        elif event.key == pygame.K_LEFT:
            self.ship.moving_left = False

    def _fire_bullet(self):
        """새 탄환을 생성하고 bullets 그룹에 추가"""
        new_bullet = Bullet(self)
        self.bullets.add(new_bullet)

        

    def _update_screen(self):
        self.screen.fill(self.setting.bg_color)

        # 우주선을 그립니다.
        self.ship.blitme()

        for bullet in self.bullets.sprites():
            bullet.draw_bullet()

        pygame.display.flip()
        

# 게임 객체를 생성합니다.
game = UniverseWar()
game.run_game

# %% [markdown]
# ### 탄환 수 제한
#
# 슈팅 게임 중에 한 화면에 존재할 수 있는 탄환수를 제한하는 경우가 있습니다. 이렇게 하면 플레이어는 좀더 정확하게 발사하려고 노력할 것입니다.
#
# 먼저 한 화면 안에서 발사할 수 있는 탄환수를 settings.py에 속성으로 추가합니다.

# %%
class Settings:
    """게임의 세팅을 저장하는 클래스"""

    def __init__(self):
        # 화면 세팅
        self.screen_width = 1200
        self.screen_height = 800
        self.bg_color = (230, 230, 230)

        # 우주선 세팅
        self.ship_speed = 1.5

        # 탄환 세팅
        self.bullet_speed = 1.0
        self.bullet_width = 3
        self.bullet_height = 15
        self.bullet_color = (60, 60, 60)
        self.bullets_allowed = 3

# %%
UniverseWar 클래스에서 이 세팅을 사용합니다. _fire_bullet() 메서드에서 새 탄환을 생성하기 전에 이미

# %%
# universe_war.py

import sys
import pygame
# 세팅 모듈 임포트
from settings import Settings
from ship import Ship
from bullet import Bullet

# 게임의 메인 처리부를 담당하는 클래스

class universeWar:
    """게임의 전체의 자원과 공작을 관리하는 클래스"""

    def __init__(self):
        pygame.init()    # 파이게임 초기화

        # Settings 인스턴스 생성
        self.settings = Settings()   # Settings 타입의 객체를 생성해서 멤버 변수에 연결

        self.screen = pygame.display.set_mode((0, 0), pygame.FULLSCREEN)  #해상도
        self.settings.screen_width = self.screen.get_rect().width
        self.settings.screen_height = self.screen.get_rect().height

        
        pygame.display.set_caption("Universe War")   # 제목 표시줄 설정

        self.ship = Ship(self)     # 우주선 객체 생성후 변수에 연결

        # se;f.bg_color = (230, 230, 230)   # 배경색 지정

    def run_game(self):
        while True:
            self._check_events()
       
            # 가장 최근에 그려진 화면을 표시합니다.
            self.ship.update()
            self.bullets.update()
            

            # 사라진 탄환을 제거합니다.
            for bullet in self.bullets.copy():
                if bullet.rect.bottom <= 0:
                    self.bullets.remove(bullet)

            self._update_screen()
            
    def _check_events(self):
         # 키보드와 마우스 이벤트를 주시합니다.
         for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == pygame.KEYDOWN:   # 키가 눌렸고
                self._check_keydown_events(event)
                
            elif event.type == pygame.KEYUP:  # 키를 눌렀다가 띄었고 
               self._check_keyup_events(event)

    

    def _check_keydown_events(self, event):
        if event.key == pygame.K_RIGHT:  # 눌린 키가 오른쪽 방향키라면
            self.ship.moving_right = True
        elif event.key == pygame.K_LEFT:   # 눌린 키가 왼쪽 방향키라면
            elf.ship.moving_left = True
        elif event.key == pygame.k_q:     # 프로그램 실행중 q 키가 입력으로 들어오면 종료
            pygame.quit()
            sys.exit()
        elif event.key == pygame.K_SPACE:
            self._fire_bullet()
            

    def _check_keyup_events(self, event):
        if event.key == pygame.K_RIGHT:
            self.ship.moving_right = False
        elif event.key == pygame.K_LEFT:
            self.ship.moving_left = False

    def _fire_bullet(self):
        """새 탄환을 생성하고 bullets 그룹에 추가"""
        if len(self.bullets) < self.settings.bullets.allowed:
            new_bullet = Bullet(self)
            self.bullets.add(new_bullet)

        

    def _update_screen(self):
        self.screen.fill(self.setting.bg_color)

        # 우주선을 그립니다.
        self.ship.blitme()

        for bullet in self.bullets.sprites():
            bullet.draw_bullet()

        pygame.display.flip()
        

# 게임 객체를 생성합니다.
game = UniverseWar()
game.run_game

# %% [markdown]
# ### _update_bullets() 메서드 레퍼토링
